# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.329950
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.870770
# Minibatch accuracy: 31.2%
# Validation accuracy: 40.3%
# Minibatch loss at step 100: 0.995213
# Minibatch accuracy: 56.2%
# Validation accuracy: 71.0%
# Minibatch loss at step 150: 0.498101
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.8%
# Minibatch loss at step 200: 0.839872
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.2%
# Minibatch loss at step 250: 1.279432
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.9%
# Minibatch loss at step 300: 0.337347
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.3%
# Minibatch loss at step 350: 0.411880
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.9%
# Minibatch loss at step 400: 0.246588
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 450: 0.795152
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 500: 0.686550
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.1%
# Minibatch loss at step 550: 0.925859
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 600: 0.220421
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 650: 1.043698
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.6%
# Minibatch loss at step 700: 0.856949
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 750: 0.087048
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 800: 0.596663
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 850: 0.954594
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 900: 0.617497
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 950: 0.495413
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 1000: 0.432426
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Test accuracy: 89.3%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.705637
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.255808
# Minibatch accuracy: 12.5%
# Validation accuracy: 22.0%
# Minibatch loss at step 100: 1.391698
# Minibatch accuracy: 43.8%
# Validation accuracy: 50.5%
# Minibatch loss at step 150: 0.693317
# Minibatch accuracy: 87.5%
# Validation accuracy: 69.3%
# Minibatch loss at step 200: 1.051065
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.9%
# Minibatch loss at step 250: 1.295656
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.9%
# Minibatch loss at step 300: 0.415920
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 350: 0.502894
# Minibatch accuracy: 93.8%
# Validation accuracy: 74.1%
# Minibatch loss at step 400: 0.373107
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 450: 0.798201
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.3%
# Minibatch loss at step 500: 0.630356
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 550: 0.538448
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 600: 0.276694
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 650: 1.096866
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 700: 0.782750
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 750: 0.038732
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.3%
# Minibatch loss at step 800: 0.577636
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 850: 0.904635
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 900: 0.543763
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 950: 0.518972
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 1000: 0.326901
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.9%
# Test accuracy: 90.7%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data, keep_prob=1):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    dropout = tf.nn.dropout(pool, keep_prob=keep_prob)
    conv = tf.nn.conv2d(dropout, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    dropout = tf.nn.dropout(pool, keep_prob=keep_prob)
    shape = dropout.get_shape().as_list()
    reshape = tf.reshape(dropout, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset, .5)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  global_step = tf.Variable(1, name='global_step', trainable=False, dtype=tf.int32)
  increment_global_step_op = tf.assign(global_step, global_step+1)
  learning_rate = tf.train.exponential_decay(0.1, global_step, 1000, 0.5, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, _, l, predictions = session.run(
      [optimizer, increment_global_step_op, loss, train_prediction], feed_dict=feed_dict)
    if (step % 100 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 5.533611
# Minibatch accuracy: 6.2%
# Validation accuracy: 7.9%
# Minibatch loss at step 100: 2.175296
# Minibatch accuracy: 6.2%
# Validation accuracy: 13.1%
# Minibatch loss at step 200: 1.908330
# Minibatch accuracy: 43.8%
# Validation accuracy: 32.0%
# Minibatch loss at step 300: 1.034588
# Minibatch accuracy: 62.5%
# Validation accuracy: 67.4%
# Minibatch loss at step 400: 0.838689
# Minibatch accuracy: 68.8%
# Validation accuracy: 72.2%
# Minibatch loss at step 500: 1.065777
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.2%
# Minibatch loss at step 600: 0.500603
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 700: 1.092152
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 800: 0.690233
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 900: 0.941839
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.7%
# Minibatch loss at step 1000: 0.629309
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 1100: 0.640941
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 1200: 1.422719
# Minibatch accuracy: 56.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 1300: 0.454473
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 1400: 0.431508
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 1500: 0.974028
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 1600: 1.130327
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.4%
# Minibatch loss at step 1700: 0.697419
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 1800: 0.606274
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 1900: 0.636492
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 2000: 0.205673
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.9%
# Minibatch loss at step 2100: 0.545056
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 2200: 0.253757
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.2%
# Minibatch loss at step 2300: 0.658123
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 2400: 0.767459
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.7%
# Minibatch loss at step 2500: 0.904901
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 2600: 0.501389
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 2700: 0.350774
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 2800: 0.851371
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 2900: 0.752030
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 3000: 0.676298
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 3100: 0.731258
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.6%
# Minibatch loss at step 3200: 0.750170
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.6%
# Minibatch loss at step 3300: 0.118666
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 3400: 0.743566
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 3500: 0.728991
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 3600: 0.167379
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 3700: 1.113406
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 3800: 0.136851
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 3900: 0.872189
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 4000: 0.431632
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# Minibatch loss at step 4100: 0.880683
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 4200: 0.795443
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 4300: 0.914873
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 4400: 1.206091
# Minibatch accuracy: 56.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 4500: 0.764777
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 4600: 0.602108
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 4700: 0.487106
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 4800: 0.486197
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 4900: 0.111874
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 5000: 1.563373
# Minibatch accuracy: 56.2%
# Validation accuracy: 85.7%
# Minibatch loss at step 5100: 0.314041
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 5200: 0.342359
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 5300: 0.451680
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 5400: 0.624462
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 5500: 0.854202
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 5600: 0.395954
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 5700: 0.459482
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 5800: 0.419490
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 5900: 0.582571
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.7%
# Minibatch loss at step 6000: 0.149823
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 6100: 0.720802
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 6200: 1.162470
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 6300: 0.494597
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 6400: 0.105685
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 6500: 0.702656
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 6600: 0.525211
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 6700: 0.276617
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 6800: 1.071332
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 6900: 0.545127
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 7000: 1.117335
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 7100: 0.715612
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 7200: 0.533808
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 7300: 0.702182
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 7400: 0.013523
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 7500: 0.458058
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 7600: 0.741894
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 7700: 0.335804
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 7800: 0.295995
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 7900: 0.158902
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 8000: 0.421714
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 8100: 0.435695
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 8200: 0.503337
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 8300: 0.464846
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 8400: 0.303624
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 8500: 0.242894
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 8600: 0.550421
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 8700: 0.226380
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 8800: 0.373910
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 8900: 0.487656
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 9000: 0.397745
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 9100: 0.561778
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 9200: 0.240939
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 9300: 1.245124
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 9400: 0.564451
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 9500: 0.298450
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 9600: 0.494290
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 9700: 0.549320
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 9800: 0.539051
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 9900: 0.928168
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 10000: 0.124160
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.1%
# Test accuracy: 93.8%
